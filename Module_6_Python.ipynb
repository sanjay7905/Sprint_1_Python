# %% [markdown]
# <h1>Module 6 - SQL</h1>
#
# <h2>Database Design</h2>
# <h4>Database</h4>
# A database is a collection of related data that is stored in an organized way.
#
# Example: A School Database stores information about students, teachers, courses, and marks.
#
# <h4>Tables</h4>
# A table is a structure inside a database that stores data in rows and columns.
#
# Example: Students Table

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID (Primary Key)
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Age
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#          <td style="border: 1px; padding: 10px; text-align: center;">
#             23
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             2
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             24
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Here, each row represents one student, and each column represents a type of information.
#
# <h2>Primary Key</h2>
#
# A primary key is a column that uniquely identifies each row in a table. It cannot contain duplicate or NULL values.
#
# Example:
#
# Student_Id

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID (Primary Key)
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             2
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Student_ID is the primary key because every student has a unique ID.
#
# <h2>Foreign Key</h2>
#
# A foreign key is a column that links one table to another by referring to the primary key of another table.
#
# Example

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID (Primary Key)
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             2
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Marks table</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#            Mark_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID (Foreign Key)
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             2
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             87
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Here, Student_ID in the Marks table is a foreign key because it refers to the Student_ID in the Students table.
#
# <h2>Relationships</h2>
#
# A relationship is the connection between two or more tables using keys.
#
# Example:
#
# One student can have many marks.
#
# The Students table is connected to the Marks table using Student_ID.

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Marks</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#            Mark_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#        <th style="border: 1px; padding: 10px;">
#             Subject
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Math
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Science
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             87
#         </td>
#     </tr>
# </table>

# %% [markdown]
# One student (101) has multiple marks, showing a relationship between the tables.
#
# <h2>Constraints</h2>
# Constraints are rules applied to table columns to ensure the data is accurate and valid.Constraints are applied while creating the table and inserting the values.
#
# Common Constraints:
#
# NOT NULL – The column cannot have an empty value.
#
# UNIQUE – All values in the column must be different.
#
# PRIMARY KEY – Uniquely identifies each row.
#
# FOREIGN KEY – Connects one table to another.
#
# CHECK – Ensures values meet a condition.
#
# DEFAULT – Assigns a default value if no value is provided.
#
# Example:
#
# CREATE TABLE Students ( Student_ID INT PRIMARY KEY, Name VARCHAR(50) NOT NULL, Age INT CHECK (Age >= 18), City VARCHAR(30) DEFAULT 'Chennai' );
#
# In this example,
#
# PRIMARY KEY makes Student_ID unique.
#
# NOT NULL ensures Name cannot be empty.
#
# CHECK ensures Age is at least 18.
#
# DEFAULT sets City to "Chennai" if no value is given

# %% [markdown]
# <h2>Queries</h2>
#
# <h3>SELECT</h3>
#
# SELECT is used to retrieve data from a table.
#
# Example:
#
# SELECT Name, Age
#
# FROM Students;
#
# This displays the Name and Age columns from the Students table.

# %% [markdown]
# <h2>WHERE</h2>
#
# WHERE is used to filter rows based on a condition.
#
# Example:
#
# SELECT *
#
# FROM Students
#
# WHERE Age > 20;
#
# This displays only students whose age is greater than 20.

# %% [markdown]
# <h2>ORDER BY</h2>
#
# ORDER BY is used to sort the result in ascending (ASC) or descending (DESC) order.
#
# Example:
#
# SELECT *
#
# FROM Students
#
# ORDER BY Age ASC;
#
# This sorts students by age from smallest to largest.

# %% [markdown]
# <h2>GROUP BY</h2>
#
# GROUP BY is used to group rows that have the same values in a column.
#
# Example:
#
# SELECT Department, COUNT(*)
#
# FROM Employees
#
# GROUP BY Department;
#
# This shows the number of employees in each department.

# %% [markdown]
# <h2>HAVING</h2>
#
# HAVING is used to filter grouped data after using GROUP BY.
#
# Example:
#
# SELECT Department, COUNT(*)
#
# FROM Employees
#
# GROUP BY Department
#
# HAVING COUNT(*) > 5;
#
# This displays only departments that have more than 5 employees.

# %% [markdown]
# <h2>DISTINCT</h2>
#
# DISTINCT is used to return only unique values by removing duplicates.
#
# Example:
#
# SELECT DISTINCT City
#
# FROM Students;
#
# If multiple students are from Chennai, it displays Chennai only once.

# %% [markdown]
# <h2>LIMIT</h2>
#
# LIMIT is used to restrict the number of rows returned.
#
# Example:
#
# SELECT *
#
# FROM Students
#
# LIMIT 5;
#
# This displays only the first 5 rows from the Students table.

# %% [markdown]
# <h2>Joins</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Suresh
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Marks table</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#            Mark_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             1
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             2
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             87
#         </td>
#     </tr>
#      <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             3
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#           103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             97
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2>INNER JOIN</h2>
#
# Returns only the rows that have matching values in both tables that are combined through a common column.
#
# Example:
#
# SELECT Students.Name, Marks.Marks
#
# FROM Students INNER JOIN Marks
#
# ON Students.Student_ID = Marks.Student_ID;
#
# Only matching records from both the tables are retreived

# %% [markdown]
# <h2>LEFT JOIN</h2>
#
# Returns all rows from the left table and the matching rows from the right table. If there is no match, NULL is returned.
#
# Example:
#
# SELECT Students.Name, Marks.Marks
#
# FROM Students LEFT JOIN Marks
#
# ON Students.Student_ID = Marks.Student_ID;
#
# All the students are shown, even if they have no marks

# %% [markdown]
# <h2>RIGHT JOIN</h2>
#
# Returns all rows from the right table and the matching rows from the left table. If there is no match, NULL is returned.
#
# Example:
#
# SELECT Students.Name, Marks.Marks
#
# FROM Students RIGHT JOIN Marks
#
# ON Students.Student_ID = Marks.Student_ID;
#
# All records from the Marks table are shown, including Student_ID 104, which has no matching student.

# %% [markdown]
# <h2>FULL JOIN</h2>
#
# Returns all rows from both tables. If there is no match, NULL is returned for the missing values.
#
# Example:
#
# SELECT Students.Name, Marks.Marks
#
# FROM Students FULL JOIN Marks
#
# ON Students.Student_ID = Marks.Student_ID;
#
# Shows all records from both tables.

# %% [markdown]
# <h2>CROSS JOIN</h2>
#
# Also called cartesian join, returns every possible combination of rows from both tables.
#
# Example:
#
# SELECT Students.Name, Marks.Marks
#
# FROM Students
#
# CROSS JOIN Marks;
#
# Every student is combined with every marks record. If there are 3 students and 3 marks records, the result contains 9 rows.

# %% [markdown]
# <h2>Advanced SQL</h2>
#
# <h3>UNION</h3>
#
# UNION combines the results of two or more SELECT queries and removes duplicate rows.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Department
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             CSE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             EEE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Suresh
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             ECE
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h2> Teachers</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Teachers_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Department
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             201
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             vishal
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             CSE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             202
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Bharathi
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             EEE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             203
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             suvan
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             IT
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ELECT Name FROM Students
#
# UNION
#
# SELECT Name FROM Teachers;
#
# Duplicate values (Rahul) appear only once.
#
# <h4>CASE</h4>
#
# CASE is used to apply conditions and return different values based on those conditions.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             87
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Suresh
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             97
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,
#
# CASE
#
# WHEN Marks >= 50 THEN 'Pass'
#
# ELSE 'Fail'
# END AS Result
#
# FROM Students;
#
# Results (Pass/Fail) is shown for each student based on their marks
#
# <h3>Subqueries</h3>
#
# A subquery is a query written inside another SQL query.
#
# Example :

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Suresh
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name
#
# FROM Students
#
# WHERE Marks = (
#
# SELECT MAX(Marks)
#
# FROM Students);
# This displays the student who has the highest marks.
#
# <h2>Common Table Expressions (CTEs)</h2>
#
# A CTE is a temporary result set created using the WITH statement. It makes complex queries easier to read.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# WITH HighMarks AS (
#
# SELECT Name, Marks
#
# FROM Students
#
# WHERE Marks > 80)
# SELECT *
#
# FROM HighMarks;
#
# This creates a temporary table called HighMarks and displays students who scored above 80.
#
# <h3>Views</h3>
#
# A view is a virtual table created from the result of a SQL query.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# CREATE VIEW TopStudents AS
#
# SELECT Name, Marks
#
# FROM Students
#
# WHERE Marks > 80;
#
# To view the data
#
# SELECT * FROM TopStudents;
#
# This displays only students who scored above 80.
#
# <h4>Indexes</h4>
#
# An index is used to speed up data retrieval from a table.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Department
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             CSE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             EEE
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Suresh
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             ECE
#         </td>
#     </tr>
# </table>

# %% [markdown]
# CREATE INDEX idx_name
#
# ON Students(Name);
#
# This creates an index on the Name column, making searches faster.
#
# <h4>Window Functions</h4>
#
# Window functions perform calculations across a set of rows without grouping them.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,Marks,RANK() OVER (ORDER BY Marks DESC) AS Rank
#
# FROM Students;
#
# This displays each student's rank while still showing every row.
#
# <h4>ROW_NUMBER()</h4>
#
# ROW_NUMBER() assigns a unique sequential number to each row.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,ROW_NUMBER() OVER (ORDER BY Marks DESC) AS Row_Num
#
# FROM Students;
#
# Each row gets a unique number.
#
# <h3>RANK()</h3>
#
# RANK() assigns a rank to each row. If there is a tie, the same rank is assigned, and the next rank is skipped.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,Marks,RANK() OVER (ORDER BY Marks DESC) AS Rank
#
# FROM Students;
#
# Rank 3 is skipped because two students share rank 2.
#
# <h2>DENSE_RANK()</h2>
#
# DENSE_RANK() assigns a rank to each row. If there is a tie, the same rank is assigned, but no ranks are skipped.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Ajun
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Karthick
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             95
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Nila
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             82
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,Marks,DENSE_RANK() OVER (ORDER BY Marks DESC) AS Dense_Rank
#
# FROM Students;
#
# No rank is skipped.
#
# <h2>LAG()</h2>
#
# LAG() returns the value from the previous row.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Meenu
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             70
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Mathi
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             80
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Sathish
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             90
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,Marks,LAG(Marks) OVER (ORDER BY Marks) AS Previous_Marks
#
# FROM Students;
#
# This shows the marks of the previous student.
#
# <h2>LEAD()</h2>
#
# LEAD() returns the value from the next row.
#
# Example:

# %% [markdown]
# <h2>Students</h2>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <tr>
#         <th style="border: 1px; padding: 10px;">
#             Student_ID
#         </th>
#         <th style="border: 1px; padding: 10px;">
#             Name
#         </th>
#     <th style="border: 1px; padding: 10px;">
#             Marks
#         </th>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             101
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Meenu
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             70
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             102
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Mathi
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             80
#         </td>
#     </tr>
#     <tr>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             103
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             Sathish
#         </td>
#         <td style="border: 1px; padding: 10px; text-align: center;">
#             90
#         </td>
#     </tr>
# </table>

# %% [markdown]
# SELECT Name,Marks,LEAD(Marks) OVER (ORDER BY Marks) AS Next_Marks
#
# FROM Students;
#
# This shows the marks of the next student.
